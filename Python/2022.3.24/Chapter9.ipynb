# %% [markdown]
# # Chapter9 함수
#
# ![image.png](attachment:ce508a6d-8fa7-4ac7-8547-99d839503770.png)

# %%
def coffeemachine(button):
    print()
    print("#1. (자동으로) 뜨거운 물을 준비한다.");
    print("#2. (자동으로) 종이컵을 준비한다.");

    if button == 1 :
         print("#3. (자동으로) 보통커피를 탄다.")
    elif button == 2 :
          print("#3. (자동으로) 설탕커피를 탄다.")
    elif button == 3 :
         print("#3. (자동으로) 블랙커피를 탄다.")
    else :
         print("#3. (자동으로) 아무거나 탄다.\n")

    print("#4. (자동으로) 물을 붓는다.");
    print("#5. (자동으로) 스푼으로 젓는다.");
    print()

# %%
coffeemachine
# Out:
# <function __main__.coffeemachine(button)>

# %%
type(coffeemachine)
# Out:
# function

# %%
# 함수호출 연산자 ()
coffeemachine(button=2)
# Out:
# #1. (자동으로) 뜨거운 물을 준비한다.
# #2. (자동으로) 종이컵을 준비한다.
# #3. (자동으로) 설탕커피를 탄다.
# #4. (자동으로) 물을 붓는다.
# #5. (자동으로) 스푼으로 젓는다.

# %% [markdown]
# 매개변수 & return

# %%
def plus(v1, v2):
    print( v1+v2 )

# %%
def plus2(v1, v2):
    return v1+v2

# %%
plus(2,2)
# Out:
# 4

# %%
plus()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 plus()
#
# TypeError: plus() missing 2 required positional arguments: 'v1' and 'v2'

# %%
plus2(2, 3)
# Out:
# 5

# %%
r = plus(2,3)
r
# Out:
# 5

# %%
def plus2(v1, v2):
    """
    plus2함수는 v1, v2 매개변수를 받는다.
     - v1: 정수
    """
    return v1+v2

# %%
plus2?
# Out:
# Signature: plus2(v1, v2)
# Docstring:
# plus2함수는 v1, v2 매개변수를 받는다.
#  - v1: 정수
# File:      c:\users\bit\appdata\local\temp\ipykernel_8348\1194281507.py
# Type:      function

# %%
plus2??
# Out:
# Signature: plus2(v1, v2)
# Source:
# def plus2(v1, v2):
#     """
#     plus2함수는 v1, v2 매개변수를 받는다.
#      - v1: 정수
#     """
#     return v1+v2
# File:      c:\users\bit\appdata\local\temp\ipykernel_8348\1194281507.py
# Type:      function

# %% [markdown]
# p265 calf() 함수

# %%
def calc(v1, v2, op) :
    result = 0
    if op == '+' :
         result = v1 + v2
    elif op == '-' :
         result = v1 - v2
    elif op == '*' :
         result = v1 * v2
    elif op == '/' :
         result = v1 / v2

    return result

# %%
calc(10, 6, '*')
# Out:
# 60

# %%
a = calc(10, 6, '*')
a
# Out:
# 60

# %%
print('10 / 6 =', calc(10, 6, "/"))
# Out:
# 10 / 6 = 1.6666666666666667

# %%
calc
# Out:
# <function __main__.calc(v1, v2, op)>

# %%
calc2 = calc

# %%
id(calc2), id(calc)
# Out:
# (2307002526160, 2307002526160)

# %%
calc2(10, 5, "+")
# Out:
# 15

# %%
# 함수의 반환!!!
def mycalc():
    return calc

# %%
mycalc
# Out:
# <function __main__.mycalc()>

# %%
mycalc(10, 5, "+")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 mycalc(10, 5, "+")
#
# TypeError: mycalc() takes 0 positional arguments but 3 were given

# %%
m = mycalc()
m
# Out:
# <function __main__.calc(v1, v2, op)>

# %%
m(10, 5, "+")
# Out:
# 15

# %%
mycalc()(10, 5, "+")
# Out:
# 15

# %% [markdown]
# # 전역변수 지역변수

# %%
a = 20

def f1():
    a = 10
    print(a)

# %%
f1()
# Out:
# 10

# %%
a = 20

def f1():
    a = 10
    print(a)
    print(locals())

# %%
f1
# Out:
# <function __main__.f1(v1, v2)>

# %%
def f2():
    print(a)

# %%
f1()
# Out:
# 10
# {'a': 10}

# %%
f2()
# Out:
# 20

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def coffeemachine(button):\n    print()\n    print("#1. (자동으로) 뜨거운 물을 준비한다.");\n    print("#2. (자동으로) 종이컵을 준비한다.");\n\n    if button == 1 :\n         print("#3. (자동으로) 보통커피를 탄다.")\n    elif button == 2 :\n          print("#3. (자동으로) 설탕커피를 탄다.")\n    elif button == 3 :\n         print("#3. (자동으로) 블랙커피를 탄다.")\n    else :\n         print("#3. (자동으로) 아무거나 탄다.\\n")\n\n    print("#4. (자동으로) 물을 붓는다.");\n    print("#5. (자동으로) 스푼으로 젓는다.");\n    print()',
#   'coffeemachine',
#   'type(coffeemachine)',
#   '# 함수호출 연산자 ()\ncoffeemachine()',
#   '# 함수호출 연산자 ()\ncoffeemachine(1)',
#   '# 함수호출 연산자 ()\ncoffeemachine(2)',
#   '# 함수호출 연산자 ()\ncoffeemachine(button=3)',
#   '# 함수호출 연산자 ()\ncoffeemachine(button=1)',
#   '# 함수호출 연산자 ()\ncoffeemachine(button=2)',
#   'def plut(v1, v2):\n    print(v1+v2)',
#   'def plus(v1, v2):\n    print(v1+v2)',
#   'del plut',
#   'plus()',
#   'plus(1,2)',
#   'plus(-2, 100)',
#   'plus(-2)',
#   'plus(-2,)',
#   'plus(-2,2,3)',
#   'plus(-2,2)',
#   'def plus(v1, v2):\n    return v1+v2',
#   'def plus(v1, v2):\n    print( v1+v2 )',
#   'def plus2(v1, v2):\n    return v1+v2',
#   'plus(-2,2)',
#   'plus(-2,2)',
#   'plus(-2,2)',
#   'plus(-2,2)',
#   'plus(2,2)',
#   'plus2(2, 3)',
#   'r = plus(2,3)\nr',
#   'def plus2(v1, v2):\n    """\n    plus2함수는 v1, v2 매개변수를 받는다.\n     - v1: 정수\n    """\n    return v1+v2',
#   "get_ipython().run_line_magic('pinfo', 'plus2')",
#   "get_ipython().run_line_magic('pinfo2', 'plus2')",
#   "def calc(v1, v2, op) :\n    result = 0\n    if op == '+' :\n         result = v1 + v2\n    elif op == '-' :\n         result = v1 - v2\n    elif op == '*' :\n         result = v1 * v2\n    elif op == '/' :\n         result = v1 / v2\n\n    return result",
#   "calc(10, 6, '*')",
#   "print('10 / 6 = {0:%05d}'.foramt(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:%05d}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:%d}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:05d}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:d}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:5}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:4}'.format(calc(10, 6, '/')))",
#   "print(f'10 / 6 = {calc(10, 6, '/'):.3f}')",
#   "print(f'10 / 6 = {calc(10, 6, '/')}')",
#   'print(f\'10 / 6 = {calc(10, 6, "/")}\')',
#   'print(f\'10 / 6 = {calc(10, 6, "/"):.2f}\')',
#   'print(f\'10 / 6 = {calc(10, 6, "/"):4.2f}\')',
#   'print(f\'10 / 6 = {calc(10, 6, "/"):0.2f}\')',
#   'print(f\'10 / 6 = {calc(10, 6, "/"):.2f}\')',
#   "calc(10, 6, '*')",
#   'print(\'10 / 6 =\', calc(10, 6, "/"))',
#   "a = calc(10, 6, '*')\na",
#   'calc',
#   'calc2 = calc',
#   'id(calc2), id(calc)',
#   'calc2(10, 5, "+")',
#   '# 함수의 반환!!!',
#   '# 함수의 반환!!!\ndef mycalc():\n    return calc',
#   'mycalc',
#   'mycalc(10, 5, "+")',
#   'm = mycalc()\nm',
#   'm(10, 5, "+")',
#   'mycalc()(10, 5, "+")',
#   'plus(2,2)',
#   'plus()',
#   'mycalc()(10, 5, "+")',
#   'a = 20\n\ndef f1():\n    a = 10\n    print(a)',
#   'f1()',
#   'a = 20\n\ndef f1():\n    a = 10\n    print(a)\n    print(locals())',
#   'f1()',
#   'globals()',
#   'a = 20\n\ndef f1():\n    a = 10\n    print(a)\n    print(globals())\n    print(locals())',
#   'f1()',
#   'a = 20\n\ndef f1():\n    a = 10\n    print(a)\n    print(locals())',
#   'f1()',
#   'globals()',
#   'globals()',
#   'globals()',
#   'globals()'],
#  '_oh': {2: <function __main__.coffeemachine(button)>,
#   3: function,
#   28: 5,
#   34: 60,
#   51: 60,
#   53: 60,
#   54: <function __main__.calc(v1, v2, op)>,
#   56: (2307002526160, 2307002526160),
#   57: 15,
#   60: <function __main__.mycalc()>,
#   62: <function __main__.calc(v1, v2, op)>,
#   63: 15,
#   64: 15,
#   67: 15,
#   72: {...},
#   77: {...},
#   78: {...},
#   79: {...}},
#  '_dh': [WindowsPath('C:/Users/BIT/Works')],
#  'In': ['',
#   'def coffeemachine(button):\n    print()\n    print("#1. (자동으로) 뜨거운 물을 준비한다.");\n    print("#2. (자동으로) 종이컵을 준비한다.");\n\n    if button == 1 :\n         print("#3. (자동으로) 보통커피를 탄다.")\n    elif button == 2 :\n          print("#3. (자동으로) 설탕커피를 탄다.")\n    elif button == 3 :\n         print("#3. (자동으로) 블랙커피를 탄다.")\n    else :\n         print("#3. (자동으로) 아무거나 탄다.\\n")\n\n    print("#4. (자동으로) 물을 붓는다.");\n    print("#5. (자동으로) 스푼으로 젓는다.");\n    print()',
#   'coffeemachine',
#   'type(coffeemachine)',
#   '# 함수호출 연산자 ()\ncoffeemachine()',
#   '# 함수호출 연산자 ()\ncoffeemachine(1)',
#   '# 함수호출 연산자 ()\ncoffeemachine(2)',
#   '# 함수호출 연산자 ()\ncoffeemachine(button=3)',
#   '# 함수호출 연산자 ()\ncoffeemachine(button=1)',
#   '# 함수호출 연산자 ()\ncoffeemachine(button=2)',
#   'def plut(v1, v2):\n    print(v1+v2)',
#   'def plus(v1, v2):\n    print(v1+v2)',
#   'del plut',
#   'plus()',
#   'plus(1,2)',
#   'plus(-2, 100)',
#   'plus(-2)',
#   'plus(-2,)',
#   'plus(-2,2,3)',
#   'plus(-2,2)',
#   'def plus(v1, v2):\n    return v1+v2',
#   'def plus(v1, v2):\n    print( v1+v2 )',
#   'def plus2(v1, v2):\n    return v1+v2',
#   'plus(-2,2)',
#   'plus(-2,2)',
#   'plus(-2,2)',
#   'plus(-2,2)',
#   'plus(2,2)',
#   'plus2(2, 3)',
#   'r = plus(2,3)\nr',
#   'def plus2(v1, v2):\n    """\n    plus2함수는 v1, v2 매개변수를 받는다.\n     - v1: 정수\n    """\n    return v1+v2',
#   "get_ipython().run_line_magic('pinfo', 'plus2')",
#   "get_ipython().run_line_magic('pinfo2', 'plus2')",
#   "def calc(v1, v2, op) :\n    result = 0\n    if op == '+' :\n         result = v1 + v2\n    elif op == '-' :\n         result = v1 - v2\n    elif op == '*' :\n         result = v1 * v2\n    elif op == '/' :\n         result = v1 / v2\n\n    return result",
#   "calc(10, 6, '*')",
#   "print('10 / 6 = {0:%05d}'.foramt(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:%05d}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:%d}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:05d}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:d}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:5}'.format(calc(10, 6, '/')))",
#   "print('10 / 6 = {0:4}'.format(calc(10, 6, '/')))",
#   "print(f'10 / 6 = {calc(10, 6, '/'):.3f}')",
#   "print(f'10 / 6 = {calc(10, 6, '/')}')",
#   'print(f\'10 / 6 = {calc(10, 6, "/")}\')',
#   'print(f\'10 / 6 = {calc(10, 6, "/"):.2f}\')',
#   'print(f\'10 / 6 = {calc(10, 6, "/"):4.2f}\')',
#   'print(f\'10 / 6 = {calc(10, 6, "/"):0.2f}\')',
#   'print(f\'10 / 6 = {calc(10, 6, "/"):.2f}\')',
#   "calc(10, 6, '*')",
#   'print(\'10 / 6 =\', calc(10, 6, "/"))',
#   "a = calc(10, 6, '*')\na",
#   'calc',
#   'calc2 = calc',
#   'id(calc2), id(calc)',
#   'calc2(10, 5, "+")',
#   '# 함수의 반환!!!',
#   '# 함수의 반환!!!\ndef mycalc():\n    return calc',
#   'mycalc',
#   'mycalc(10, 5, "+")',
#   'm = mycalc()\nm',
#   'm(10, 5, "+")',
#   'mycalc()(10, 5, "+")',
#   'plus(2,2)',
#   'plus()',
#   'mycalc()(10, 5, "+")',
#   'a = 20\n\ndef f1():\n    a = 10\n    print(a)',
#   'f1()',
#   'a = 20\n\ndef f1():\n    a = 10\n    print(a)\n    print(locals())',
#   'f1()',
#   'globals()',
#   'a = 20\n\ndef f1():\n    a = 10\n    print(a)\n    print(globals())\n    print(locals())',
#   'f1()',
#   'a = 20\n\ndef f1():\n    a = 10\n    print(a)\n    print(locals())',
#   'f1()',
#   'globals()',
#   'globals()',
#   'globals()',
#   'globals()'],
#  'Out': {2: <function __main__.coffeemachine(button)>,
#   3: function,
#   28: 5,
#   34: 60,
#   51: 60,
#   53: 60,
#   54: <function __main__.calc(v1, v2, op)>,
#   56: (2307002526160, 2307002526160),
#   57: 15,
#   60: <function __main__.mycalc()>,
#   62: <function __main__.calc(v1, v2, op)>,
#   63: 15,
#   64: 15,
#   67: 15,
#   72: {...},
#   77: {...},
#   78: {...},
#   79: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x0000021923543460>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x21923543b80>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x21923543b80>,
#  '_': {...},
#  '__': {...},
#  '___': {...},
#  '_i': 'globals()',
#  '_ii': 'globals()',
#  '_iii': 'globals()',
#  '_i1': 'def coffeemachine(button):\n    print()\n    print("#1. (자동으로) 뜨거운 물을 준비한다.");\n    print("#2. (자동으로) 종이컵을 준비한다.");\n\n    if button == 1 :\n         print("#3. (자동으로) 보통커피를 탄다.")\n    elif button == 2 :\n          print("#3. (자동으로) 설탕커피를 탄다.")\n    elif button == 3 :\n         print("#3. (자동으로) 블랙커피를 탄다.")\n    else :\n         print("#3. (자동으로) 아무거나 탄다.\\n")\n\n    print("#4. (자동으로) 물을 붓는다.");\n    print("#5. (자동으로) 스푼으로 젓는다.");\n    print()',
#  'coffeemachine': <function __main__.coffeemachine(button)>,
#  '_i2': 'coffeemachine',
#  '_2': <function __main__.coffeemachine(button)>,
#  '_i3': 'type(coffeemachine)',
#  '_3': function,
#  '_i4': '# 함수호출 연산자 ()\ncoffeemachine()',
#  '_i5': '# 함수호출 연산자 ()\ncoffeemachine(1)',
#  '_i6': '# 함수호출 연산자 ()\ncoffeemachine(2)',
#  '_i7': '# 함수호출 연산자 ()\ncoffeemachine(button=3)',
#  '_i8': '# 함수호출 연산자 ()\ncoffeemachine(button=1)',
#  '_i9': '# 함수호출 연산자 ()\ncoffeemachine(button=2)',
#  '_i10': 'def plut(v1, v2):\n    print(v1+v2)',
#  '_i11': 'def plus(v1, v2):\n    print(v1+v2)',
#  'plus': <function __main__.plus(v1, v2)>,
#  '_i12': 'del plut',
#  '_i13': 'plus()',
#  '_i14': 'plus(1,2)',
#  '_i15': 'plus(-2, 100)',
#  '_i16': 'plus(-2)',
#  '_i17': 'plus(-2,)',
#  '_i18': 'plus(-2,2,3)',
#  '_i19': 'plus(-2,2)',
#  '_i20': 'def plus(v1, v2):\n    return v1+v2',
#  '_i21': 'def plus(v1, v2):\n    print( v1+v2 )',
#  '_i22': 'def plus2(v1, v2):\n    return v1+v2',
#  'plus2': <function __main__.plus2(v1, v2)>,
#  '_i23': 'plus(-2,2)',
#  '_i24': 'plus(-2,2)',
#  '_i25': 'plus(-2,2)',
#  '_i26': 'plus(-2,2)',
#  '_i27': 'plus(2,2)',
#  '_i28': 'plus2(2, 3)',
#  '_28': 5,
#  '_i29': 'r = plus(2,3)\nr',
#  'r': None,
#  '_i30': 'def plus2(v1, v2):\n    """\n    plus2함수는 v1, v2 매개변수를 받는다.\n     - v1: 정수\n    """\n    return v1+v2',
#  '_i31': 'plus2?',
#  '_i32': 'plus2??',
#  '_i33': "def calc(v1, v2, op) :\n    result = 0\n    if op == '+' :\n         result = v1 + v2\n    elif op == '-' :\n         result = v1 - v2\n    elif op == '*' :\n         result = v1 * v2\n    elif op == '/' :\n         result = v1 / v2\n\n    return result",
#  'calc': <function __main__.calc(v1, v2, op)>,
#  '_i34': "calc(10, 6, '*')",
#  '_34': 60,
#  '_i35': "print('10 / 6 = {0:%05d}'.foramt(calc(10, 6, '/')))",
#  '_i36': "print('10 / 6 = {0:%05d}'.format(calc(10, 6, '/')))",
#  '_i37': "print('10 / 6 = {0:%d}'.format(calc(10, 6, '/')))",
#  '_i38': "print('10 / 6 = {0}'.format(calc(10, 6, '/')))",
#  '_i39': "print('10 / 6 = {0:05d}'.format(calc(10, 6, '/')))",
#  '_i40': "print('10 / 6 = {0:d}'.format(calc(10, 6, '/')))",
#  '_i41': "print('10 / 6 = {0}'.format(calc(10, 6, '/')))",
#  '_i42': "print('10 / 6 = {0:5}'.format(calc(10, 6, '/')))",
#  '_i43': "print('10 / 6 = {0:4}'.format(calc(10, 6, '/')))",
#  '_i44': "print(f'10 / 6 = {calc(10, 6, '/'):.3f}')",
#  '_i45': "print(f'10 / 6 = {calc(10, 6, '/')}')",
#  '_i46': 'print(f\'10 / 6 = {calc(10, 6, "/")}\')',
#  '_i47': 'print(f\'10 / 6 = {calc(10, 6, "/"):.2f}\')',
#  '_i48': 'print(f\'10 / 6 = {calc(10, 6, "/"):4.2f}\')',
#  '_i49': 'print(f\'10 / 6 = {calc(10, 6, "/"):0.2f}\')',
#  '_i50': 'print(f\'10 / 6 = {calc(10, 6, "/"):.2f}\')',
#  '_i51': "calc(10, 6, '*')",
#  '_51': 60,
#  '_i52': 'print(\'10 / 6 =\', calc(10, 6, "/"))',
#  '_i53': "a = calc(10, 6, '*')\na",
#  'a': 20,
#  '_53': 60,
#  '_i54': 'calc',
#  '_54': <function __main__.calc(v1, v2, op)>,
#  '_i55': 'calc2 = calc',
#  'calc2': <function __main__.calc(v1, v2, op)>,
#  '_i56': 'id(calc2), id(calc)',
#  '_56': (2307002526160, 2307002526160),
#  '_i57': 'calc2(10, 5, "+")',
#  '_57': 15,
#  '_i58': '# 함수의 반환!!!',
#  '_i59': '# 함수의 반환!!!\ndef mycalc():\n    return calc',
#  'mycalc': <function __main__.mycalc()>,
#  '_i60': 'mycalc',
#  '_60': <function __main__.mycalc()>,
#  '_i61': 'mycalc(10, 5, "+")',
#  '_i62': 'm = mycalc()\nm',
#  'm': <function __main__.calc(v1, v2, op)>,
#  '_62': <function __main__.calc(v1, v2, op)>,
#  '_i63': 'm(10, 5, "+")',
#  '_63': 15,
#  '_i64': 'mycalc()(10, 5, "+")',
#  '_64': 15,
#  '_i65': 'plus(2,2)',
#  '_i66': 'plus()',
#  '_i67': 'mycalc()(10, 5, "+")',
#  '_67': 15,
#  '_i68': 'a = 20\n\ndef f1():\n    a = 10\n    print(a)',
#  'f1': <function __main__.f1()>,
#  '_i69': 'f1()',
#  '_i70': 'a = 20\n\ndef f1():\n    a = 10\n    print(a)\n    print(locals())',
#  '_i71': 'f1()',
#  '_i72': 'globals()',
#  '_72': {...},
#  '_i73': 'a = 20\n\ndef f1():\n    a = 10\n    print(a)\n    print(globals())\n    print(locals())',
#  '_i74': 'f1()',
#  '_i75': 'a = 20\n\ndef f1():\n    a = 10\n    print(a)\n    print(locals())',
#  '_i76': 'f1()',
#  '_i77': 'globals()',
#  '_77': {...},
#  '_i78': 'globals()',
#  '_78': {...},
#  '_i79': 'globals()',
#  '_79': {...},
#  '_i80': 'globals()'}

# %%
a
# Out:
# 20

# %%
def f3():
    global a     # 로컬에서 a라는 전역변수를 그대로 사용!
    a = 30
    print(a)

# %%
f3()
# Out:
# 30

# %%
a
# Out:
# 30

# %% [markdown]
# 여러 반환값 처리

# %%
def multi(v1, v2) :
     retList=[]       # 반환할 리스트
     res1 = v1 + v2
     res2 = v1 - v2
     retList.append(res1)
     retList.append(res2)
     return retList

# %%
myList = []
hap, sub = 0, 0

# %%
myList = multi(100, 200)

# %%
myList
# Out:
# [300, -100]

# %%
hap = myList[0]
sub = myList[1]
print("multi()에서 돌려준 값 ==> %d, %d" % (hap, sub))
# Out:
# multi()에서 돌려준 값 ==> 300, -100

# %%
def multi(v1, v2) :
    res1 = v1 + v2
    res2 = v1 - v2
    return res1, res2, res2, res1

# %%
multi(100,2000)
# Out:
# (2100, -1900, -1900, 2100)

# %%
r = multi(100,2000)
r
# Out:
# (2100, -1900, -1900, 2100)

# %%
r[0]
# Out:
# 2100

# %%
a, b, c, d = multi(100,2000)

# %%
a, b, c, d
# Out:
# (2100, -1900, -1900, 2100)

# %% [markdown]
# pass

# %%
def f1():
    pass

# %%
f1()

# %%
if True:
    pass
else:
    print('End')

# %% [markdown]
# # 매개변수 전달

# %%
def f1(v1, v2):
    return v1 + v2

# %%
def f2(v1,v2,v3):
    return v1+v2+v3

# %%
f1(10, 20)
# Out:
# 30

# %%
f2(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [109], in <cell line: 1>()
# ----> 1 f2(1,2)
#
# TypeError: f2() missing 1 required positional argument: 'v3'

# %%
def f2(v1,v2,v3):
    return v1+v2+v3

# %%
f2(1,2,0)
# Out:
# 3

# %% [markdown]
# 매개변수 기본값

# %%
def f3(v1,v2,v3=0):  # 매개변수 값이 전달이 안되면 기본값!!!
    return v1+v2+v3

# %%
f3(1,2,3)
# Out:
# 6

# %%
f3(1,2)
# Out:
# 3

# %%
f3(v1=1,v2=3,v3=4)
# Out:
# 8

# %%
f3(v1=1,v2=3)
# Out:
# 4

# %%
f3(v1=1,v3=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [117], in <cell line: 1>()
# ----> 1 f3(v1=1,v3=3)
#
# TypeError: f3() missing 1 required positional argument: 'v2'

# %%
f3(v1=1, v3=3, v2=2)
# Out:
# 6

# %% [markdown]
# `*`, `**` 매개변수

# %%
def f4(*v):
    result = 0
    for n in v:
        result += n
    return result

# %%
def f3(v1,v2,v3=0):  # 매개변수 값이 전달이 안되면 기본값!!!
    return v1+v2+v3

# %%
f4
# Out:
# <function __main__.f4(*v)>

# %%
f4(1, 2, 3)
# Out:
# 6

# %%
f4(1)
# Out:
# 1

# %% [markdown]
# 딕셔너리 매개변수

# %%
def f5(**v): #dict
    for k in v.keys():
        print('%s --> %d 명' % (k, v[k]))

# %%
f5(v1=1, v2=3, v3=0)
# Out:
# v1 --> 1 명
# v2 --> 3 명
# v3 --> 0 명

# %%
f5(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [126], in <cell line: 1>()
# ----> 1 f5(1,2,3)
#
# TypeError: f5() takes 0 positional arguments but 3 were given

# %% [markdown]
# 가변형 인자 & 딕셔너리 인자

# %%
def myfunction(*args, **kwargs):
    print('args: ', args)
    print('kwargs: ', kwargs)

# %%
myfunction()
# Out:
# args:  ()
# kwargs:  {}

# %%
myfunction(1)
# Out:
# args:  (1,)
# kwargs:  {}

# %%
myfunction(a=3)
# Out:
# args:  ()
# kwargs:  {'a': 3}

# %%
myfunction(1,2,3,a=3)
# Out:
# args:  (1, 2, 3)
# kwargs:  {'a': 3}

# %%
myfunction(a=3, 2, 3)
# Out:
#   Input In [132]
#     myfunction(a=3, 2, 3)
#                     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# # 모듈
#
#  - `import MODULE`
#  - `import MODULE as alias`
#  - `from MODULE import function`

# %%
import Module1

# %%
type(Module1)
# Out:
# module

# %%
Module1
# Out:
# <module 'Module1' from 'C:\\Users\\BIT\\Works\\Module1.py'>

# %%
Module1.PI
# Out:
# 3.14

# %%
Module1.func1()
# Out:
# module1.py func1()

# %%
Module1.func1
# Out:
# <function Module1.func1()>

# %%
import Module1 as m1

# %%
m1.func2()
# Out:
# module1.py func2()

# %%
# 모듈 안의 특정한 객체만 가져올 때!!!

# %%
from Module1 import func1, func2

# %%
func1()
# Out:
# module1.py func1()

# %%
func2()
# Out:
# module1.py func2()

# %% [markdown]
# ## Module2 테스트

# %%
# %ls *.py
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: C494-BA4F
#
#  C:\Users\BIT\Works 디렉터리
#
# 2022-03-24  오후 03:08               164 Module1.py
# 2022-03-24  오후 03:19                65 Module2.py
#                2개 파일                 229 바이트
#                0개 디렉터리  66,674,405,376 바이트 남음

# %%
# !python Module2.py
# Out:
# Module2 --> func1()

# %%
# 다른사람.
import Module2
# Out:
# Module2 --> func1()

# %%
Module2.func1()
# Out:
# Module2 --> func1()

# %% [markdown]
# p86 쪽 `__main__`

# %% [markdown]
# ### `__main__` 적용
#
#  - C/Java 컴파일러 언어 -> start point!!!
#      - 시작하는 함수!!
#
#  - startpoint 대체
#  - 모듈의 테스트 코드

# %%
# !python Module3.py
# Out:
# Module3 --> func1()

# %%
import Module3

# %%
import sys
print(sys.builtin_module_names)
# Out:
# ('_abc', '_ast', '_bisect', '_blake2', '_codecs', '_codecs_cn', '_codecs_hk', '_codecs_iso2022', '_codecs_jp', '_codecs_kr', '_codecs_tw', '_collections', '_contextvars', '_csv', '_datetime', '_functools', '_heapq', '_imp', '_io', '_json', '_locale', '_lsprof', '_md5', '_multibytecodec', '_opcode', '_operator', '_pickle', '_random', '_sha1', '_sha256', '_sha3', '_sha512', '_signal', '_sre', '_stat', '_statistics', '_string', '_struct', '_symtable', '_thread', '_tracemalloc', '_warnings', '_weakref', '_winapi', '_xxsubinterpreters', 'array', 'atexit', 'audioop', 'binascii', 'builtins', 'cmath', 'errno', 'faulthandler', 'gc', 'itertools', 'marshal', 'math', 'mmap', 'msvcrt', 'nt', 'parser', 'sys', 'time', 'winreg', 'xxsubtype', 'zlib')

# %%
dir(Module3)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'func1']

# %%
Module3.__name__
# Out:
# 'Module3'

# %% [markdown]
# ### 실습: p277 예제 로또 코드
#
# 1. getNumber 를 LottoModule.py 에 정의한다.
# 2. LottoModule 을 가져와 p277 코드를 완성한다.

# %%
import LottoModule as lm

# %%
lotto = []
num = 0

print("** 로또 추첨을 시작합니다. ** \n");

while True :
     num = lm.getNumber()

     if lotto.count(num) == 0 :
          lotto.append(num)

     if len(lotto) >= 6 :
          break 

print("추첨된 로또 번호 ==>  ", end = '')
lotto.sort()
for i in range(0, 6) :
     print("%d  " % lotto[i], end = '')
# Out:
# ** 로또 추첨을 시작합니다. **
#
# 추첨된 로또 번호 ==>  1  29  35  39  42  43

# %% [markdown]
# ## 패키지

# %%
import mypackage.Module3

# %%
mypackage.Module3.func1()
# Out:
# Module3 --> func1()

# %%
from mypackage import Module3

# %% [markdown]
# ## Lambda 함수
#
# `lambda` 키워 -> 이름이 없는 함수를 만든다!

# %%
hap2 = lambda x, y: x + y

# %%
type(hap2)
# Out:
# function

# %%
hap2
# Out:
# <function __main__.<lambda>(x, y)>

# %%
hap2(100, 200)
# Out:
# 300

# %%
hap2 = lambda x=10, y=20: x + y

# %%
hap2()
# Out:
# 30

# %%
li = [1,2,3,4,5]

result = list(map(lambda x: x+10, li))
print(result)
# Out:
# [11, 12, 13, 14, 15]

# %% [markdown]
# ### 재귀함수

# %%
def selfcall():
    print('Hello', end='')
    selfcall()

# %%
selfcall()
# Out:
# ...
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 selfcall()
#
# Input In [37], in selfcall()
#       1 def selfcall():
#       2     print('Hello', end='')
# ----> 3     selfcall()
#
# Input In [37], in selfcall()
#       1 def selfcall():
#       2     print('Hello', end='')
# ----> 3     selfcall()
#
#     [... skipping similar frames: selfcall at line 3 (2964 times)]
#
# Input In [37], in selfcall()
#       1 def selfcall():
#       2     print('Hello', end='')
# ----> 3     selfcall()
#
# Input In [37], in selfcall()
#       1 def selfcall():
# ----> 2     print('Hello', end='')
#       3     selfcall()
#
# File ~\anaconda3\envs\Lecture\lib\site-packages\ipykernel\iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File ~\anaconda3\envs\Lecture\lib\site-packages\ipykernel\iostream.py:213, in IOPubThread.schedule(self, f)
#     208 def schedule(self, f):
#     209     """Schedule a function to be called in our IO thread.
#     210
#     211     If the thread is not running, call immediately.
#     212     """
# --> 213     if self.thread.is_alive():
#     214         self._events.append(f)
#     215         # wake event thread (message content is ignored)
#
# File ~\anaconda3\envs\Lecture\lib\threading.py:1082, in Thread.is_alive(self)
#    1080 if self._is_stopped or not self._started.is_set():
#    1081     return False
# -> 1082 self._wait_for_tstate_lock(False)
#    1083 return not self._is_stopped
#
# File ~\anaconda3\envs\Lecture\lib\threading.py:1027, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1025 if lock is None:  # already determined that the C code is done
#    1026     assert self._is_stopped
# -> 1027 elif lock.acquire(block, timeout):
#    1028     lock.release()
#    1029     self._stop()
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
